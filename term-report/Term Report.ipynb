# %%
import pandas as pd
from pathlib import Path

# %%
input_file = Path.cwd()/'data'/'raw'/'course_income.csv'

# %%
df = pd.read_csv(input_file)

# %%
df
# Out:
#                                                Course   Code  \
# 0                                 Yoga - Autumn Break   AB11
# 1   Botanical Ink Drawing for Beginners One Day Wo...   AB19
# 2                      Workshop: The Art of Découpage   AB20
# 3               Spanish Conversation Club - Beginners  AB21a
# 4            Spanish Conversation Club - Intermediate  AB21b
# ..                                                ...    ...
# 76                     Cryptic Crosswords Friday Club   SC30
# 77       WA Mahjong 1-day Festival - mahjongwa.org.au   SC32
# 78                         SPLC Current Affairs Forum   SC33
# 79  St John WA Automated External Defibrillator (A...    T38
# 80                                                NaN    NaN
#
#           First Session  Day    Start  Sessions  Tot-Stus  Concession-Stus  \
# 0     4-Apr-2023 4:15pm  Tue   4:15pm         3         3                0
# 1    14-Apr-2023 9:00am  Fri   9:00am         1         5                0
# 2   12-Apr-2023 10:30am  Wed  10:30am         1         4                0
# 3    6-Apr-2023 10:00am  Thu  10:00am         4         3                0
# 4    6-Apr-2023 11:00am  Thu  11:00am         4         3                0
# ..                  ...  ...      ...       ...       ...              ...
# 76    5-May-2023 9:30am  Fri   9:30am         8         4                0
# 77   15-Apr-2023 9:00am  Sat   9:00am         1        96                1
# 78    1-May-2023 2:15pm  Mon   2:15pm         8        11                0
# 79   14-Jun-2023 3:00pm  Wed   3:00pm         1        20                0
# 80                  NaN  NaN      NaN       411       506               34
#
#        CM Fee Operating Fee Concession Fee Total Income
# 0       $4.05        $90.00          $0.00      $165.00
# 1       $2.25       $300.00          $0.00      $800.00
# 2       $1.80       $105.00          $0.00      $300.00
# 3       $5.40         $0.00          $0.00      $120.00
# 4       $5.40         $0.00          $0.00      $120.00
# ..        ...           ...            ...          ...
# 76     $14.40         $0.00          $0.00      $220.00
# 77     $21.70         $0.00          $0.00    $1,940.00
# 78     $37.60         $0.00          $0.00      $660.00
# 79      $6.50       $240.00          $0.00        $0.00
# 80  $1,076.70         23535          $0.00   $40,535.71
#
# [81 rows x 12 columns]

# %% [markdown]
# ## Lose the unwanted columns

# %%
df.drop(['Day','Start','Concession-Stus','CM Fee','Concession Fee'], axis=1, inplace=True)

# %% [markdown]
# ## Remove the dollar sign and comma from e.g. $1,500

# %%
df['Total Income']=df['Total Income'].str.lstrip('$')
df['Operating Fee']=df['Operating Fee'].str.lstrip('$')
df['Total Income']=df['Total Income'].str.replace(',','')
df['Operating Fee']=df['Operating Fee'].str.replace(',','')

# %% [markdown]
# ## Change the strings to numeric

# %%
df['Total Income']=df['Total Income'].str.lstrip('$')
df['Operating Fee']=df['Operating Fee'].str.lstrip('$')
df['Total Income']=df['Total Income'].str.replace(',','')
df['Operating Fee']=df['Operating Fee'].str.replace(',','')
df['Total Income']=pd.to_numeric(df['Total Income'])
df['Operating Fee']=pd.to_numeric(df['Operating Fee'])

# %% [markdown]
# ## Calculate and add the Profit column

# %%
df['Profit']=df['Total Income']-df['Operating Fee']

# %% [markdown]
# ## Sort by Profit

# %%
df = df.sort_values('Profit', ascending=False)

# %%
df
# Out:
#                                                Course   Code  \
# 80                                                NaN    NaN
# 77       WA Mahjong 1-day Festival - mahjongwa.org.au   SC32
# 20                Brilliant Watercolour for Beginners   AC64
# 19                Botanical Ink Beginners and Ongoing   AC63
# 72                             Mahjong Wednesday Club   SC15
# ..                                                ...    ...
# 15                               Ikebana Japanese Art  AC26a
# 52                                French Intermediate     L7
# 14                               Ikebana Japanese Art  AC26a
# 79  St John WA Automated External Defibrillator (A...    T38
# 12                        Advanced Drawing Techniques   AC7b
#
#           First Session  Sessions  Tot-Stus  Operating Fee  Total Income  \
# 80                  NaN       411       506        23535.0      40535.71
# 77   15-Apr-2023 9:00am         1        96            0.0       1940.00
# 20   2-May-2023 12:30pm         9        10          900.0       2000.00
# 19    2-May-2023 9:30am         9        10          900.0       2000.00
# 72    3-May-2023 9:30am         8        18            0.0       1080.00
# ..                  ...       ...       ...            ...           ...
# 15  13-Jun-2023 10:00am         3         6          360.0        290.62
# 52   3-May-2023 11:00am         8         3          600.0        480.00
# 14  14-Mar-2023 10:00am         3         6          360.0        206.25
# 79   14-Jun-2023 3:00pm         1        20          240.0          0.00
# 12    4-May-2023 9:30am         8         4          960.0        690.00
#
#       Profit
# 80  17000.71
# 77   1940.00
# 20   1100.00
# 19   1100.00
# 72   1080.00
# ..       ...
# 15    -69.38
# 52   -120.00
# 14   -153.75
# 79   -240.00
# 12   -270.00
#
# [81 rows x 8 columns]

# %%
df = df[["Course","Code","First Session","Sessions","Tot-Stus","Total Income","Operating Fee","Profit"]]

# %%
df
# Out:
#                                                Course   Code  \
# 80                                                NaN    NaN
# 77       WA Mahjong 1-day Festival - mahjongwa.org.au   SC32
# 20                Brilliant Watercolour for Beginners   AC64
# 19                Botanical Ink Beginners and Ongoing   AC63
# 72                             Mahjong Wednesday Club   SC15
# ..                                                ...    ...
# 15                               Ikebana Japanese Art  AC26a
# 52                                French Intermediate     L7
# 14                               Ikebana Japanese Art  AC26a
# 79  St John WA Automated External Defibrillator (A...    T38
# 12                        Advanced Drawing Techniques   AC7b
#
#           First Session  Sessions  Tot-Stus  Total Income  Operating Fee  \
# 80                  NaN       411       506      40535.71        23535.0
# 77   15-Apr-2023 9:00am         1        96       1940.00            0.0
# 20   2-May-2023 12:30pm         9        10       2000.00          900.0
# 19    2-May-2023 9:30am         9        10       2000.00          900.0
# 72    3-May-2023 9:30am         8        18       1080.00            0.0
# ..                  ...       ...       ...           ...            ...
# 15  13-Jun-2023 10:00am         3         6        290.62          360.0
# 52   3-May-2023 11:00am         8         3        480.00          600.0
# 14  14-Mar-2023 10:00am         3         6        206.25          360.0
# 79   14-Jun-2023 3:00pm         1        20          0.00          240.0
# 12    4-May-2023 9:30am         8         4        690.00          960.0
#
#       Profit
# 80  17000.71
# 77   1940.00
# 20   1100.00
# 19   1100.00
# 72   1080.00
# ..       ...
# 15    -69.38
# 52   -120.00
# 14   -153.75
# 79   -240.00
# 12   -270.00
#
# [81 rows x 8 columns]

# %%
df.to_csv('hurrah.csv',index=False)
